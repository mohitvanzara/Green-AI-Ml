# %%
import cv2

# %%
img1 = cv2.imread('img1.jpg')
img2 = cv2.imread('img2.jpg')

# %%
img1.shape
img2.shape
# Out:
# (183, 275, 3)

# %%
h = 225
w = 225
newSize = (h,w)
img1NEW = cv2.resize(img1,newSize)
# Out:
# (225, 225, 3)

# %%
img1NEW.shape

# %%
img = img1NEW+img2
cv2.imshow('addimg',img)

cv2.waitKey(0)
