# %%
import cv2
import numpy as np

# %%
img1 = cv2.imread('img1.jpg')
img2 = cv2.imread('img2.jpg')

# %%
img1.shape
img2.shape
# Out:
# (225, 225, 3)

# %%
h = 225
w = 225
newSize = (h,w)
img1NEW = cv2.resize(img1,newSize)

# %%
img1NEW.shape
# Out:
# (225, 225, 3)

# %%
# img = img1NEW+img2
# cv2.imshow('addimg',img)

# cv2.waitKey(0)

# %%
# kernal = np.array([[0,0,0],[0,1,0],[0,0,0]])
# img2 = cv2.filter2D(img1,-1,kernal) # -1 d-depth
# cv2.imshow('filter',img2)
# cv2.waitKey(0)

# %%
b,g,r = cv2.split(img1)
# cv2.imshow('blue',b)
# cv2.imshow('green',g)
# cv2.imshow('red',r)
# cv2.waitKey(0)

# %%
z = b+g+r
cv2.imshow('z',z)
cv2.waitKey(0)
k = cv2.merge((b,g,r))
cv2.imshow('k',k)
